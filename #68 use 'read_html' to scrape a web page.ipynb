# %%
import pandas as pd

# %%
url = 'http://ranking.promisingedu.com/qs'
ranking = pd.read_html(url)

# %%
ranking
# Out:
# [     Ranking                            University English Name  \
#  0          1        麻省理工学院Massachusetts Institute of Technology
#  1          2                           斯坦福大学Stanford University
#  2          3                             哈佛大学Harvard University
#  3          4                           牛津大学University of Oxford
#  4          5        加利福尼亚理工学院California Institute of Technology
#  5          6  ETH Zurich - Swiss Federal Institute of Techno...
#  6          7                        剑桥大学University of Cambridge
#  7          8                    伦敦大学学院University College London
#  8          9                      帝国理工学院Imperial College London
#  9         10                     芝加哥大学The University of Chicago
#  10        11  Nanyang Technological University, Singapore (NTU)
#  11        11             National University of Singapore (NUS)
#  12        13                         普林斯顿大学Princeton University
# ...

# %%
type(ranking)
# Out:
# list

# %%
len(ranking)
# Out:
# 1

# %%
ranking[0]
# Out:
#      Ranking                            University English Name  \
# 0          1        麻省理工学院Massachusetts Institute of Technology
# 1          2                           斯坦福大学Stanford University
# 2          3                             哈佛大学Harvard University
# 3          4                           牛津大学University of Oxford
# 4          5        加利福尼亚理工学院California Institute of Technology
# 5          6  ETH Zurich - Swiss Federal Institute of Techno...
# 6          7                        剑桥大学University of Cambridge
# 7          8                    伦敦大学学院University College London
# 8          9                      帝国理工学院Imperial College London
# 9         10                     芝加哥大学The University of Chicago
# 10        11  Nanyang Technological University, Singapore (NTU)
# 11        11             National University of Singapore (NUS)
# 12        13                         普林斯顿大学Princeton University
# 13        14                            康奈尔大学Cornell University
# ...
